# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## BGR

# %%
bright = cv2.imread('../../../class.vision/images/cube-bright.png')
dark = cv2.imread('../../../class.vision/images/cube-dark.png')

#show
plt.figure(figsize=[11,11])
plt.subplot(331);plt.imshow(bright[...,::-1]);plt.title("bright");
plt.subplot(332);plt.imshow(dark[...,::-1]);plt.title("dark");

plt.subplot(334);plt.imshow(bright[...,0], cmap='gray');plt.title("bright-blue");
plt.subplot(335);plt.imshow(bright[...,1], cmap='gray');plt.title("bright-green");
plt.subplot(336);plt.imshow(bright[...,2], cmap='gray');plt.title("bright-red");

plt.subplot(337);plt.imshow(dark[...,0], cmap='gray');plt.title("dark-blue");
plt.subplot(338);plt.imshow(dark[...,1], cmap='gray');plt.title("dark-green");
plt.subplot(339);plt.imshow(dark[...,2], cmap='gray');plt.title("dark-red");

# %% [markdown]
# ## HSV

# %%
brightHSV = cv2.cvtColor(bright, cv2.COLOR_BGR2HSV)
darkHSV = cv2.cvtColor(dark, cv2.COLOR_BGR2HSV)

#show
plt.figure(figsize=[11,11])
plt.subplot(331);plt.imshow(bright[...,::-1]);plt.title("bright");
plt.subplot(332);plt.imshow(dark[...,::-1]);plt.title("dark");

plt.subplot(334);plt.imshow(brightHSV[...,0], cmap='gray');plt.title("bright-hue");
plt.subplot(335);plt.imshow(brightHSV[...,1], cmap='gray');plt.title("bright-saturation");
plt.subplot(336);plt.imshow(brightHSV[...,2], cmap='gray');plt.title("bright-value");

plt.subplot(337);plt.imshow(darkHSV[...,0], cmap='gray');plt.title("dark-hue");
plt.subplot(338);plt.imshow(darkHSV[...,1], cmap='gray');plt.title("dark-saturation");
plt.subplot(339);plt.imshow(darkHSV[...,2], cmap='gray');plt.title("dark-value");

# %% [markdown]
# ## LAB

# %%
brightLAB = cv2.cvtColor(bright, cv2.COLOR_BGR2LAB)
darkLAB = cv2.cvtColor(dark, cv2.COLOR_BGR2LAB)

#show
plt.figure(figsize=[11,11])
plt.subplot(331);plt.imshow(bright[...,::-1]);plt.title("bright");
plt.subplot(332);plt.imshow(dark[...,::-1]);plt.title("dark");

plt.subplot(334);plt.imshow(brightLAB[...,0], cmap='gray');plt.title("bright-l");
plt.subplot(335);plt.imshow(brightLAB[...,1], cmap='gray');plt.title("bright-a");
plt.subplot(336);plt.imshow(brightLAB[...,2], cmap='gray');plt.title("bright-b");

plt.subplot(337);plt.imshow(darkLAB[...,0], cmap='gray');plt.title("dark-l");
plt.subplot(338);plt.imshow(darkLAB[...,1], cmap='gray');plt.title("dark-a");
plt.subplot(339);plt.imshow(darkLAB[...,2], cmap='gray');plt.title("dark-b");

# %% [markdown]
# ## YCrCb

# %%
brightYCrCb = cv2.cvtColor(bright, cv2.COLOR_BGR2YCrCb)
darkYCrCb = cv2.cvtColor(dark, cv2.COLOR_BGR2YCrCb)

#show
plt.figure(figsize=[11,11])
plt.subplot(331);plt.imshow(bright[...,::-1]);plt.title("bright");
plt.subplot(332);plt.imshow(dark[...,::-1]);plt.title("dark");

plt.subplot(334);plt.imshow(brightYCrCb[...,0], cmap='gray');plt.title("bright-Y");
plt.subplot(335);plt.imshow(brightYCrCb[...,1], cmap='gray');plt.title("bright-Cr");
plt.subplot(336);plt.imshow(brightYCrCb[...,2], cmap='gray');plt.title("bright-Cb");

plt.subplot(337);plt.imshow(darkYCrCb[...,0], cmap='gray');plt.title("dark-Y");
plt.subplot(338);plt.imshow(darkYCrCb[...,1], cmap='gray');plt.title("dark-Cr");
plt.subplot(339);plt.imshow(darkYCrCb[...,2], cmap='gray');plt.title("dark-Cb");
