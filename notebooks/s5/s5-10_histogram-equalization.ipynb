# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('default')
plt.style.use('seaborn-v0_8-whitegrid')

# %%
xray_img = cv.imread('../../../class.vision/images/xray.jpg', 0)
satellite_img = cv.imread('../../../class.vision/images/satellite.jpg', 0)
low_contrast_img = cv.imread('../../../class.vision/images/low-contrast.jpg', 0)
mid_img = cv.imread('../../../class.vision/images/mid.png')

# %%
result = cv.equalizeHist(xray_img)

plt.subplot(221), plt.imshow(xray_img, cmap='gray')
plt.subplot(222), plt.imshow(result, cmap='gray')
plt.subplot(223), plt.hist(xray_img.ravel(), bins=256)
plt.subplot(224), plt.hist(result.ravel(), bins=256)
plt.show()
