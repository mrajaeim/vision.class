# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("../../images/transparency.png", cv2.IMREAD_UNCHANGED)
img.shape
# Out:
# (901, 749, 4)

# %%
bgr_img = img[...,0:3]
alpha_img = img[...,-1]
plt.imshow(bgr_img[...,::-1]); plt.title("RGB image")
# Out:
# Text(0.5, 1.0, 'RGB image')

# %%
plt.imshow(alpha_img, cmap="gray");plt.title("Alpha channel")
# Out:
# Text(0.5, 1.0, 'Alpha channel')
