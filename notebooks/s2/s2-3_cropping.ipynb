# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("../../images/2.png")
plt.imshow(img[...,::-1])

# %%
cropped_img = img[100:300, 580:680, :]
plt.imshow(cropped_img[...,::-1])

# %%
cv2.imshow("Orginal", img)
cv2.imshow("Cropped", cropped_img)

cv2.waitKey()
cv2.destroyAllWindows()
